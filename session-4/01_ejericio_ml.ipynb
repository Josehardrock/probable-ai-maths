# %% [markdown]
# Ejercicio 1.
# Utilizando Python, implemente un algoritmo que analice el conjunto de datos de calidad de vinos.
# Instrucciones:
# 1. Cargar el conjunto de datos a través de la función load_wine() de sklearn.datasets
# 2. Realizar un análisis exploratorio para entender las relaciones entre las características.
# 3. Decidir si una regresión lineal múltiple, un modelo polinómico, o un modelo basado en
# árboles es más adecuado.
# 4. Crear y entrenar el modelo seleccionado.
# 5. Evaluar la precisión del modelo y discutir las razones de la elección del modelo.
# Ejercicio 2.
# Usando Python implemente un algoritmo que analice el conjunto de datos de dígitos manuscritos.
# Instrucciones:
# 1. Cargar el conjunto de datos a través de la función load_digits() de sklearn.datasets
# 2. Realizar un análisis exploratorio para entender las características del conjunto de datos.
# 3. Elegir un modelo de clasificación apropiado (como Regresión Logística, Árboles de
# Decisión o Random Forests).
# 4. Preprocesar los datos si es necesario (normalización, codificación de etiquetas, división en
# conjuntos de entrenamiento y prueba).
# 5. Entrenar el modelo de clasificación seleccionado con los datos.
# 6. Evaluar el modelo utilizando métricas relevantes como Accuracy, Precision, Recall, y F1
# Score

# %%
from sklearn.datasets import load_wine 

quality_wine = load_wine()

print(quality_wine.data)
print(quality_wine.__class__.)
# Out:
# [[1.423e+01 1.710e+00 2.430e+00 ... 1.040e+00 3.920e+00 1.065e+03]
#  [1.320e+01 1.780e+00 2.140e+00 ... 1.050e+00 3.400e+00 1.050e+03]
#  [1.316e+01 2.360e+00 2.670e+00 ... 1.030e+00 3.170e+00 1.185e+03]
#  ...
#  [1.327e+01 4.280e+00 2.260e+00 ... 5.900e-01 1.560e+00 8.350e+02]
#  [1.317e+01 2.590e+00 2.370e+00 ... 6.000e-01 1.620e+00 8.400e+02]
#  [1.413e+01 4.100e+00 2.740e+00 ... 6.100e-01 1.600e+00 5.600e+02]]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\tools\anaconda3\envs\obspython3-9\lib\site-packages\sklearn\utils\_bunch.py:54, in Bunch.__getattr__(self, key)
#      53 try:
# ---> 54     return self[key]
#      55 except KeyError:
#
# File c:\tools\anaconda3\envs\obspython3-9\lib\site-packages\sklearn\utils\_bunch.py:39, in Bunch.__getitem__(self, key)
#      35     warnings.warn(
#      36         self._deprecated_key_to_warnings[key],
# ...
